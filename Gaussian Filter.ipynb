# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

image= cv2.imread(r"F:\ObjectDetection\brain_MR.jpg")
image_copy = np.copy(image)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)

# %%
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)

gray_blur= cv2.GaussianBlur(gray,(9,9),0)

f, (ax1,ax2) = plt.subplots(1,2 ,figsize=(20,10))
ax1.set_title("Original Image")
ax1.imshow(gray , cmap='gray')

ax2.set_title("blurred Image")
ax2.imshow(gray_blur , cmap='gray')

# %%
sobel_x = np.array([[-1,0,1],
    [-2,0,2],
                  [-1,0,1]])
sobel_y = np.array(sobel_x.T)

filtered= cv2.filter2D(gray, -1, sobel_x)
filtered_blurred = cv2.filter2D(gray_blur, -1 , sobel_x)
filtered_blurred2 = cv2.filter2D(gray_blur, -1 , sobel_y)
f, (ax1,ax2) = plt.subplots(1,2 ,figsize=(20,10))
ax1.set_title("Y")
ax1.imshow(filtered_blurred2 , cmap='gray')

ax2.set_title("X")
ax2.imshow(filtered_blurred , cmap='gray')

# %%
retval, binary_image = cv2.threshold(filtered_blurred , 50,255, cv2.THRESH_BINARY)
plt.imshow(binary_image, cmap='gray')
